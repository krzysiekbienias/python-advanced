# %% [markdown]
# Modified duration mówi: o ile procent zmieni się cena obligacji przy zmianie rentowności o 1 punkt procentowy (100 bps).

# %% [markdown]
# $$
# \frac{\Delta P}{P} \approx -D_{\text{mod}}\cdot \Delta y
# $$

# %%
D=8
delta_y=0.02

# %%
-8*0.02
# Out:
# -0.16

# %% [markdown]
# Czyli cena spadla o 16%

# %% [markdown]
# a teraz dodamy do tego jeszcze Convexity C=80

# %% [markdown]
# $$
# \frac{\Delta P}{P} \approx -D_{\text{mod}}\Delta y + \tfrac{1}{2}C(\Delta y)^2
# $$

# %%
-8*0.02+0.5*80*0.02**2
# Out:
# -0.14400000000000002
