# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
def add_event(e,events=[]):
    events.append(e)
    return events

# %%
add_event("a")
add_event("b")
# Out:
# ['a']
# ['a', 'b']

# %%
def add_event(e,events=None):
    if events is None:
        events=[]
    events.append(e)
    return events

# %%
add_event("a")
add_event("b")
# Out:
# ['a']
# ['b']
