# %%
def loud(func):
    def wrapper():
        return func().upper()+"!!!"
    return wrapper

# %% [markdown]
# It is important that we are passing the reference to the function wrapper not invocation so NOT return wrapper()

# %%
def greet():
    return 'HELLO, THERE!!!'

# %%
laud_greet=loud(greet)
laud_greet()
# Out:
# 'HELLO, THERE!!!!!!'
